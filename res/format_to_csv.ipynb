# %%
import pandas as pd

# %%
df = pd.read_table("optimaDataset_14.dat")

# %%
df
# Out:
#             ID  DestAct  NbTransf  TimePT  WalkingTimePT  WaitingTimePT  \
# 0     28241083        1         1      51             25              2
# 1     53060420        3         3     200             20             14
# 2     92460717        4         0       0              2              0
# 3     47130281        2         0      30             20              0
# 4     95241108        9         5     231             68             43
# 5     44670208        1         0     122            102              0
# 6     90320845        7         1      42             11              4
# 7     42270212        1         5     261             87             14
# 8     44630527        1         4     164             42             12
# 9     39010095        4         1     117             44             12
# 10    90300346        1         2      69             41              2
# 11    19130912        4         0      94             44              0
# ...

# %%
df.to_csv("optimaDataset_14.csv")
